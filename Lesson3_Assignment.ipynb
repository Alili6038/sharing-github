# %% [markdown]
# ## 1. 实现`print`函数
# 定义一个函数`print_string`，返回一个字符串。
# `print_string`函数支持输入多个参数，每个参数间使用参数`sep`(默认一个空格)的字符进行连接，并且最后还要添加一个`end`(默认一个换行)参数的字符。
# 比如
# - `print_string('This is a test')` 返回`This is a test\n`
# - `print_string('This', 'is', 'a', 'test')` 返回`This is a test\n`
# - `print_string('This', 'is', 'a', 'test', sep = '-')` 返回`This-is-a-test\n`
# - `print_string('This', 'is', 'a', 'test', ',', 'Yes', sep = '_', end = '.')` 返回`This_is_a_test_,_Yes.`

# %%
def print_string(*sths, sep=' ', end='\n'):
    
    
    """
    This function is to print a string.
    """
    
    string_ = ''
    
    for sth in sths:
        
        string_ += sth
        string_ += sep
    
    string_ += end
    
    return string_
    
        
    
print_string('This', 'is', 'a', 'test', ',', 'Yes', sep = '_', end = '.')
# Out:
# 'This_is_a_test_,_Yes_.'

# %% [markdown]
# ## 2. 打印斐波那契数列
# 以三种方式打印斐波那契数列
# 给定一个数值n，将前n项的波那契数列打印出来

# %%
def Fibonacci(n):
    
    """
    This function is to print Fibonacci series
    """
    
    Fibo = []
    Fibo_0 = 0
    
    if n == 0:
        
        print('Enter a positive number to check the Fibonacci terms!')
        
    elif n == 1:
        
        Fibo.append(1)
    
    elif n == 2:
        
        
        Fibo.append(1)
        Fibo.append(1)
    
    else:
        
        Fibo.append(1)
        Fibo.append(1)
        for i in range(n-2):
            
            Fibo.append(Fibo[i]+Fibo[i+1])
            
    return Fibo
    
Fibonacci(3)
# Out:
# [1, 1, 2]

# %%
def Fibonacci(n):
    
    """
    This function is to print Fibonacci series
    """
    
    #Fibo = []
    Fibo_0 = 0
    if n == 1:
        
        return 1
    
    elif n == 2:
        
        return Fibo_0 + Fibonacci(n-1)
        #Fibo.append(1)*2 # not possible, error
        #Fibo.append(1)
    
    else:
        
        return Fibonacci(n-1) + Fibonacci(n-2)
    
Fibonacci(5)
# Out:
# 5

# %% [markdown]
# <font size = 5>
#
# # Question:
#
#     Please have a look of the previous cell,
#
#     I write the Fibonacci function to return the nth term
#
#       instead of the first n terms
#
#
#     But this method use recursion, so I think it is a good practice
#
#     Just to ask:
#
#     Is there any way to use recursion in a function
#
#     to return a list
#
#     instead of a no. in this specific Fibonacci function question

# %%
def Fibonacci(n):
    
    """
    This function is to print Fibonacci series
    """
    
    Fibo = []
    Fibo_0 = 0
    
    if n == 0:
        
        print('Enter a positive number to check the Fibonacci terms!')
        
    elif n == 1:
        
        Fibo.append(1)
    
    elif n == 2:
        
        def Fibonacci_2(m):
            
            Fibo_2 = []
            
            Fibo.append(1)
            Fibo.append(1)
        Fibonacci_2(2)
        
    
    else:
        
        def Fibonacci_2(m):
            
            Fibo_2 = []
            
            Fibo.append(1)
            Fibo.append(1)
        Fibonacci_2(2)
        for i in range(n-2):
            
            Fibo.append(Fibo[i]+Fibo[i+1])
            
    return Fibo
    
Fibonacci(4)
# Out:
# [1, 1, 2, 3]

# %%
def Fibonacci(n):
    
    """
    This function is to print Fibonacci series
    """
    
    Fibo_0, Fibo_1 = 0, 1
    count = 0
    #Fibo_middle = 0
    
    if n < 1:
        
        print('Enter a positive no. !')
        
    elif n == 1:
        
        print(Fibo_1)
        
    else:
        
        
        while n > count:
        
            
            Fibo_middle = Fibo_0 + Fibo_1
            Fibo_0 = Fibo_1
            Fibo_1 = Fibo_middle
            count += 1
            print(Fibo_0)
            
Fibonacci(0)
# Out:
# Enter a positive no. !
